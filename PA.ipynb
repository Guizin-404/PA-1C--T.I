# %%
# input Num
idade = 25
print(idade)
altura = 1.78
numero_complexo = 2 + 3j
# text
nome = 'Lucas Lindinho'
#bool
esta_chovendo = False
#
# Out:
# 25

# %% [markdown]
# Algortimo de calcula o quadrado
#
# #Entrada
#
# Ler o Dado
#
# #Processamento
#
# multiplica o lado pelo lado
#
# #Saida
#
# Mostrar Resultado

# %%
# Entrada
lado = 6

# Processamento
quadrado = lado * lado

# Saida
print(f"total da area dos quadrados:{quadrado}")
# Out:
# total da area dos quadrados:36

# %%
Tamanho = float(input("digite o tamanho da sala em metros: "))
comprimento = float(input("digite o comprimento da sala em metros: "))
area = Tamanho * comprimento
print(f"a area da sala é: {area}m²")
# Out:
# digite o tamanho da sala em metros: 2
# digite o comprimento da sala em metros: 348538
# a area da sala é: 697076.0m²

# %% [markdown]
# Escrever um algoritimo e o programa que recebe 04 notas e calcula a media dos alunos e exibe a media

# %%
n1 = float(input("digite a primeira nota: "))
n2 = float(input("digite a segunda nota: "))
n3 = float(input("digite a terceira nota: "))
n4 = float(input("digite a quarta nota: "))
md = (n1 + n2 + n3 + n4) / 4
print(f"a media do aluno é: {md}")
# Out:
# digite a primeira nota: 10
# digite a segunda nota: 10
# digite a terceira nota: 10
# digite a quarta nota: 9.75
# a media do aluno é: 9.9375

# %%
num = float(input("digite um numero: "))
dob = num * 2
print(f"O Dobro do número selecionado é: {dob}")
# Out:
# digite um numero: 98
# O Dobro do número selecionado é: 196.0
