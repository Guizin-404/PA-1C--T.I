# %% [markdown]
# Questão 1 – Classificação de idade
#
# Crie um programa que leia a idade de uma pessoa e classifique conforme as regras abaixo:
# 	•	Até 17 anos: Menor de idade
# 	•	De 18 a 59 anos: Adulto
# 	•	60 anos ou mais: Idoso
#
# Questão 2 – Cálculo de desconto
#
# Crie um programa que leia o valor de uma compra e aplique o desconto conforme as regras:
# 	•	Até R$100: sem desconto
# 	•	De R$101 a R$500: 10% de desconto
# 	•	Acima de R$500: 20% de desconto
# Ao final, mostre o valor final da compra.
#
# Questão 3 – Verificação de triângulo
#
# Crie um programa que leia três valores e verifique se eles podem formar um triângulo.
# Para isso, a soma de dois lados deve ser maior que o terceiro.
# Mostre uma mensagem informando se é ou não um triângulo válido.
#
#
# Questão 4 – Sistema de energia (jogo)
#
# Crie um programa que leia a energia de um personagem (de 0 a 100) e classifique:
# 	•	0: Morto
# 	•	1 a 30: Crítico
# 	•	31 a 70: Normal
# 	•	71 a 100: Saudável
#
#
# Questão 5 – Média escolar
#
# Crie um programa que leia a média final de um aluno e classifique:
# 	•	Média maior ou igual a 7: Aprovado
# 	•	Média entre 5 e 6.9: Recuperação
# 	•	Média menor que 5: Reprovado
#
# Questão 6 – Cálculo de salário com bônus
#
# Crie um programa que leia o salário de um funcionário e sua pontuação de desempenho. O programa deve calcular um bônus de acordo com as regras:
# 	•	Pontuação menor que 5: sem bônus
# 	•	Pontuação de 5 a 7: bônus de 5% do salário
# 	•	Pontuação de 8 a 9: bônus de 10% do salário
# 	•	Pontuação igual a 10: bônus de 15% do salário

# %% [markdown]
# questão 01

# %%
id = int(input("Digite a sua idade: "))
print('=-'*10)
print(f"      {id} anos")
print('=-'*10)

if id <= 17:
    print(f"Você tem tem {id} anos, você é menor de idade.")

if (id >= 18) and (id <= 59):
    print(f"Você tem tem {id} anos, você é Adulto.")
    
if id >= 60:
    print(f"Você tem tem {id} anos, você é Idoso.")
# Out:
# =-=-=-=-=-=-=-=-=-=-
#       20 anos
# =-=-=-=-=-=-=-=-=-=-
# Você tem tem 20 anos, você é Adulto.

# %% [markdown]
# questão 02

# %%
valor = float(input("digite o valor total da compra: "))
print('=-'*15)
print(f"valor da compra: R$: {valor}")
print('=-'*15)

if (valor >= 101) and (valor <= 500):
    calc = valor * 0.10
    total = valor - calc
    print(f"O valor total da sua compra com 10% de desconto é de: {total}")

if valor > 500:
    calc = valor * 0.20
    total = valor - calc
    print(f"O valor total da sua compra com 20% de desconto é de: {total}")

if valor <= 100:
    print(f"O valor total da sua compra é de: {valor}")
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# valor da compra: R$: 200.0
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# O valor total da sua compra com 10% de desconto é de: 180.0

# %% [markdown]
# questão 03

# %%
print('-='*10)
print('Analizador de Triângulos')
print('-='*10)
r1 = float (input("Digite o Tamanho do Primeiro Segmento do Triângulo: "))
r2 = float (input("Digite o Tamanho do Segundo Segmento do Triângulo: "))
r3 = float (input("Digite o Tamanho do Terceiro Segmento do Triângulo: "))
calculo = r1 + r2
if r3 <= calculo:
  print("Essas Rotas Formão um Triângulo!!!!")
else:
    print("Essas Rotas não Formão um triângulo")
# Out:
# -=-=-=-=-=-=-=-=-=-=
# Analizador de Triângulos
# -=-=-=-=-=-=-=-=-=-=
# Essas Rotas Formão um Triângulo!!!!

# %% [markdown]
# questão 04

# %%
hp = int(input("Digite a energia do seu personagem: "))
print('=-'*10)
print(f"{hp} de energia")
print('=-'*10)

if (hp >= 71) and (hp <= 100):
    print(f"O seu personagem ainda está com {hp} de energia, ele está saudável")

if (hp >= 31) and (hp <= 70):
    print(f"O seu personagem ainda está com {hp} de energia, ele está Normal")

if (hp >= 1) and (hp <= 30):
    print(f"O seu personagem ainda está com {hp} de energia, ele está em estado Critico")

if hp == 0:
    print(f"Você está com {hp} de energia, você está Morto")
# Out:
# =-=-=-=-=-=-=-=-=-=-
# 80 de energia
# =-=-=-=-=-=-=-=-=-=-
# O seu personagem ainda está com 80 de energia, ele está saudável

# %% [markdown]
# questão 05

# %%
n1 = int(input("digite a primeira nota do aluno: "))
print('=-'*10)
print(n1)
n2 = int(input("digite a segunda nota do aluno: "))
print('=-'*10)
print(n2)
n3 = int(input("digite a terceira nota do aluno: "))
print('=-'*10)
print(n3)
n4 = int(input("digite a quarta nota do aluno: "))
print('=-'*10)
print(n4)
print('=-'*10)


calc = (n1 + n2 + n3 + n4) / 4

if calc >= 7:
    print(f"A media do aluno foi de {calc} ele está APROVADO")

if calc >= 5 and calc <= 6.9:
    print(f"A media do aluno foi de {calc} ele está de RECUPERACÃO")

if calc < 5:
    print(f"A media do aluno foi de {calc} ele está REPROVADO")
# Out:
# =-=-=-=-=-=-=-=-=-=-
# 7
# =-=-=-=-=-=-=-=-=-=-
# 6
# =-=-=-=-=-=-=-=-=-=-
# 8
# =-=-=-=-=-=-=-=-=-=-
# 10
# =-=-=-=-=-=-=-=-=-=-
# A media do aluno foi de 7.75 ele está APROVADO

# %% [markdown]
# questão 06

# %%
salario = float(input("Digite o seu salário: "))
pont = int(input("Digite a pontuação do funcionario: "))
print('=-'*10)
print(f'salario R$: {salario}')
print('=-'*10)
print(f"{pont} pontos")
print('=-'*10)



if pont < 5:
    print(f"você recebera R$: {salario} ")

if pont >= 5 and pont <= 7:
    calc = salario * 0.05
    total = salario + calc
    print(f"Você ganhou 5% de bonus e recebera R$: {total}")

if pont >= 8 and pont <= 9:
    calc = salario * 0.10
    total = salario + calc
    print(f"Você ganhou 10% de bonus e recebera R$: {total}")

if pont == 10:
    calc = salario * 0.15
    total = salario + calc
    print(f"Você ganhou 15% de bonus e recebera R$: {total}")
# Out:
# =-=-=-=-=-=-=-=-=-=-
# salario R$: 1000.0
# =-=-=-=-=-=-=-=-=-=-
# 10 pontos
# =-=-=-=-=-=-=-=-=-=-
# Você ganhou 15% de bonus e recebera R$: 1150.0
